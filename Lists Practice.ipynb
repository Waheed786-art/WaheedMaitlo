# %%
item = ["Haji" , "Farhan" , "Faiz" , "Rehan"]
item.pop()
print(item)
item.insert(4 , "Ahsan")
print(item)
item.remove("Faiz")
print(item)

cars = ["Civic" , "Audi" , "Rolls Royce" , "Vitz"]
print("Here is the original List: " , cars)
print("\nHere is the sorted List: " , sorted(cars))  # Sorted is used for temporary sorting.
print("Here is the original List again: " , cars)
cars.sort()
print("Here is the permanently sorted List: " ,cars)# cars.sort , this type of sort is used for permanent sorting.
too_expensive = "Civic"
cars.remove(too_expensive)
print("\nA " + too_expensive.title() + " is too expensive for me.")  
print(cars)
cars.reverse()
print("This is the reversed order ", cars)

invited = ["Shoaib" , "Hasnain" , "Shahriyar", "Jinsar"]
invited.remove("Jinsar")
invited.insert(3, "Parvez")
invited.append("Saqib")        
print(invited)



locations = ["Murree" , "Paris" , "London" , "Amsterdam" , "Bangkok"]
locations.append("New York")
print(sorted(locations , reverse = True )) # temporarily sorted
print(locations)
locations.reverse()
print(locations)
locations.reverse()
print(locations)
locations.sort(reverse = True)  # sorted permanently and reversed after sorting.
print(locations)
print(len(locations))
print(locations[-1])
locations.pop(0)
print(locations)
del locations[0]
print(locations)

work = ["CD" , "Unique" , "Crown"]
print(work.index("Crown"))

pizzas = ["Shawarma", "Fajita" , "Pepperoni"]
for pizza in pizzas:
    print(f"He likes {pizza} Flavour of Pizza.")
    
animals = ["Dog" , "Lion", "Wolf"]
for animal in animals:
    print(f"{animal} is the bravest animal of all.") if animal == "Lion" else print(f"{animal} is the most loyal animal of all.") if animal == "Dog" else print(f"{animal} is the most intelligent animal of all.") if animal == "Wolf" else print("Nothing!")
print("These all animals are mammals.")
# Out:
# ['Haji', 'Farhan', 'Faiz']
# ['Haji', 'Farhan', 'Faiz', 'Ahsan']
# ['Haji', 'Farhan', 'Ahsan']
# Here is the original List:  ['Civic', 'Audi', 'Rolls Royce', 'Vitz']
#
# Here is the sorted List:  ['Audi', 'Civic', 'Rolls Royce', 'Vitz']
# Here is the original List again:  ['Civic', 'Audi', 'Rolls Royce', 'Vitz']
# Here is the permanently sorted List:  ['Audi', 'Civic', 'Rolls Royce', 'Vitz']
#
# A Civic is too expensive for me.
# ['Audi', 'Rolls Royce', 'Vitz']
# This is the reversed order  ['Vitz', 'Rolls Royce', 'Audi']
# ['Shoaib', 'Hasnain', 'Shahriyar', 'Parvez', 'Saqib']
# ['Paris', 'New York', 'Murree', 'London', 'Bangkok', 'Amsterdam']
# ['Murree', 'Paris', 'London', 'Amsterdam', 'Bangkok', 'New York']
# ['New York', 'Bangkok', 'Amsterdam', 'London', 'Paris', 'Murree']
# ['Murree', 'Paris', 'London', 'Amsterdam', 'Bangkok', 'New York']
# ['Paris', 'New York', 'Murree', 'London', 'Bangkok', 'Amsterdam']
# 6
# Amsterdam
# ...
