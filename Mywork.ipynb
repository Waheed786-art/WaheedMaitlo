# %%
class student:
    school = "School of Excellence"
    def details(self):
        print(f"The name of the student is {self.name} and he is currently studing in {self.school}.")
    @classmethod
    def new_name(cls , new):
        cls.school = new
    
a = student()
a.new_name("The leaders academy")
a.name = "Waheed"
a.details()

class teacher:
    school = "The Punjab CSS and PMS Academy"
    def __init__(self , name):
        self.name = name
    def detail(self):
        print(f"The name is {self.name} and he is teacher at {self.school}.")
    @property
    def new(self):
        return self.name
    @new.setter
    def new(self, new_one):
        self.name = new_one
        return self.name

b = teacher("Sajid")
b.school = "Oxford School"
b.new = "Naveed"
b.detail()
t = [2 ,4 ,7 , 1 ,8, 19]
def func_filter(a):
    return a > 5

fl = list(filter(func_filter , t))
print(fl)

cb = list(map(lambda x: x*x*x , t))
print(cb)
from functools import reduce


def new_function(a, b):
    return a + b

rd = reduce(new_function, t)
print(rd)
    
    
class clerk:
    school = "Excellence School Sukkur"
    def __init__(self, name , salary):
        self.name = name
        self.salary = salary
    @classmethod
    def new(cls , ne):
        return cls (ne.split(" ")[0], int(ne.split(" ")[1]))
ne = "Ali 15000"
a2 = clerk.new(ne)
print(f"The name of the clerk is {a2.name} and he works in {clerk.school} his salary is around {a2.salary}")

lis = ["Car" , "bike" , "truck"]
lis.sort(reverse = True)
print(lis)

def careful(name):
    def name1(*args, **kwargs):
        print("Start")
        name(*args, **kwargs)
        print("End")
    return name1

def fun1(s, e):
    print(s+e)
careful(fun1)(2 , 3)
# Out:
# The name of the student is Waheed and he is currently studing in The leaders academy.
# The name is Naveed and he is teacher at Oxford School.
# [7, 8, 19]
# [8, 64, 343, 1, 512, 6859]
# 41
# The name of the clerk is Ali and he works in Excellence School Sukkur his salary is around 15000
# ['truck', 'bike', 'Car']
# Start
# 5
# End
